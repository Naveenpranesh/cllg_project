# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import itertools
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn import metrics
df_pandas = pd.read_csv('dataset/diabetes.csv')
df_pandas.head()
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
df_pandas.info()
missing_values_table(df_pandas)
diabetes_map = {1:1, 0:2}
df_pandas['Outcome'] = df_pandas['Outcome'].map(diabetes_map)
# mark zero values as missing or NaN
df_pandas = df_pandas.replace(0, np.NaN)
# fill missing values with mean column values
df_pandas.fillna(df_pandas.mean(), inplace=True)
diabetes_map = {1:1, 2:0}
df_pandas['Outcome'] = df_pandas['Outcome'].map(diabetes_map)
# count the number of NaN values in each column
print(df_pandas.isnull().sum())
df_nn = df_pandas
df_pandas.head()
sns.heatmap(df_pandas[df_pandas.columns[:8]].corr(),annot=True,cmap='RdYlGn')
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()
sns.countplot(x='Outcome',data=df_pandas)
plt.show()
columns=df_pandas.columns[:8]
plt.subplots(figsize=(18,15))
length=len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    df_pandas[i].hist(bins=20,edgecolor='black')
    plt.title(i)
plt.show()
diab1=df_pandas[df_pandas['Outcome']==1]
columns=df_pandas.columns[:8]
plt.subplots(figsize=(18,15))
length=len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    diab1[i].hist(bins=20,edgecolor='black')
    plt.title(i)
plt.show()
sns.pairplot(data=df_pandas,hue='Outcome',diag_kind='hist')
plt.show()




###   Gradient Boosting
dataset = pd.read_csv('dataset/diabetes.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 8].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
from sklearn.ensemble import GradientBoostingClassifier
gbe = GradientBoostingClassifier(random_state=42)
parameters={'learning_rate': [0.05, 0.1, 0.5],
            'max_features': [0.5, 1],
            'max_depth': [3, 4, 5]
}
gridsearch=GridSearchCV(gbe, parameters, cv=100, scoring='roc_auc')
gridsearch.fit(X, y)
print(gridsearch.best_params_)
print(gridsearch.best_score_)
gbi = GradientBoostingClassifier(learning_rate=0.05, max_depth=3,
                                 max_features=0.5,
                                 random_state=42)
X_train,X_test,y_train, y_test = train_test_split(X, y, random_state=42)
gbi.fit(X_train, y_train)
y_pred = gbi.predict_proba(X_test)[:,1]
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred.round())
print('TP - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))


###   Apply Feed Forward Neural Network & Evaulate Results.
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
dl_epoch = 100													
model = Sequential()
model.add(Dense(500, input_dim=8,init='uniform' ,activation='relu'))
model.add(Dense(100, init='uniform',activation='relu'))
model.add(Dense(1, init='uniform',activation='sigmoid'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train,y_train, epochs=dl_epoch, batch_size=70, validation_data=(X_test, y_test))
plt.rcParams["figure.figsize"] = [20, 10]

for key in history.history.keys():
    plt.plot(range(1, dl_epoch+1), history.history[key])

plt.legend(list(history.history.keys()), loc='upper left')
plt.title('Key Matrics vs Epochs for Diabetes Data')
plt.show()

###   ADABOOST CLASSIFIER

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 8].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier(n_estimators=50, learning_rate=1)

model = abc.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred.round())
print('TP - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))
###   Apply Feed Forward Neural Network & Evaulate Results.

from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
dl_epoch = 100

model = Sequential()
model.add(Dense(500, input_dim=8,init='uniform' ,activation='relu'))
model.add(Dense(100, init='uniform',activation='relu'))
model.add(Dense(1, init='uniform',activation='sigmoid'))
model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train,y_train, epochs=dl_epoch, batch_size=70, validation_data=(X_test, y_test))

plt.rcParams["figure.figsize"] = [20, 10]

for key in history.history.keys():
    plt.plot(range(1, dl_epoch+1), history.history[key])

plt.legend(list(history.history.keys()), loc='upper left')
plt.title('Key Matrics vs Epochs for Diabetes Data')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Your selected dataframe has 9 columns.
# There are 0 columns that have missing values.
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# {'learning_rate': 0.05, 'max_depth': 3, 'max_features': 0.5}
# 0.8399999999999999
# TP - True Negative 96
# FP - False Positive 27
# FN - False Negative 21
# TP - True Positive 48
# Accuracy Rate: 0.75
# Misclassification Rate: 0.25
# Using Theano backend.
# <ipython-input-2-59540b2a70fb>:127: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(500, input_dim=8, activation="relu", kernel_initializer="uniform")`
#   model.add(Dense(500, input_dim=8,init='uniform' ,activation='relu'))
# <ipython-input-2-59540b2a70fb>:128: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="relu", kernel_initializer="uniform")`
#   model.add(Dense(100, init='uniform',activation='relu'))
# <ipython-input-2-59540b2a70fb>:129: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   model.add(Dense(1, init='uniform',activation='sigmoid'))
# Train on 576 samples, validate on 192 samples
# Epoch 1/100
# 576/576 [==============================] - 0s 234us/step - loss: 0.2871 - acc: 0.6042 - val_loss: 0.2599 - val_acc: 0.6354
# Epoch 2/100
# 576/576 [==============================] - 0s 242us/step - loss: 0.2406 - acc: 0.6354 - val_loss: 0.2345 - val_acc: 0.6458
# Epoch 3/100
# 576/576 [==============================] - 0s 235us/step - loss: 0.2278 - acc: 0.6615 - val_loss: 0.2268 - val_acc: 0.6667
# Epoch 4/100
# 576/576 [==============================] - 0s 246us/step - loss: 0.2175 - acc: 0.6840 - val_loss: 0.2275 - val_acc: 0.6615
# Epoch 5/100
# 576/576 [==============================] - 0s 265us/step - loss: 0.2098 - acc: 0.6840 - val_loss: 0.2195 - val_acc: 0.6667
# Epoch 6/100
# 576/576 [==============================] - 0s 257us/step - loss: 0.2104 - acc: 0.6667 - val_loss: 0.2087 - val_acc: 0.6771
# Epoch 7/100
# 576/576 [==============================] - 0s 231us/step - loss: 0.2012 - acc: 0.7170 - val_loss: 0.2092 - val_acc: 0.6771
# Epoch 8/100
# 576/576 [==============================] - 0s 221us/step - loss: 0.2005 - acc: 0.6806 - val_loss: 0.2053 - val_acc: 0.7083
# Epoch 9/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1966 - acc: 0.6858 - val_loss: 0.2084 - val_acc: 0.6823
# Epoch 10/100
# 576/576 [==============================] - 0s 234us/step - loss: 0.1987 - acc: 0.6823 - val_loss: 0.2209 - val_acc: 0.6615
# Epoch 11/100
# 576/576 [==============================] - 0s 311us/step - loss: 0.2127 - acc: 0.6858 - val_loss: 0.2111 - val_acc: 0.7031
# Epoch 12/100
# 576/576 [==============================] - 0s 240us/step - loss: 0.2029 - acc: 0.6944 - val_loss: 0.2066 - val_acc: 0.6823
# Epoch 13/100
# 576/576 [==============================] - 0s 258us/step - loss: 0.1921 - acc: 0.7118 - val_loss: 0.2032 - val_acc: 0.6979
# Epoch 14/100
# 576/576 [==============================] - 0s 256us/step - loss: 0.1903 - acc: 0.7205 - val_loss: 0.2003 - val_acc: 0.7031
# Epoch 15/100
# 576/576 [==============================] - 0s 242us/step - loss: 0.1903 - acc: 0.7188 - val_loss: 0.2001 - val_acc: 0.7031
# Epoch 16/100
# 576/576 [==============================] - 0s 261us/step - loss: 0.1918 - acc: 0.7049 - val_loss: 0.2011 - val_acc: 0.6979
# Epoch 17/100
# 576/576 [==============================] - 0s 230us/step - loss: 0.1915 - acc: 0.6944 - val_loss: 0.2053 - val_acc: 0.7031
# Epoch 18/100
# 576/576 [==============================] - 0s 229us/step - loss: 0.1926 - acc: 0.6997 - val_loss: 0.2001 - val_acc: 0.7292
# Epoch 19/100
# 576/576 [==============================] - 0s 242us/step - loss: 0.1845 - acc: 0.7292 - val_loss: 0.2048 - val_acc: 0.6875
# Epoch 20/100
# 576/576 [==============================] - 0s 228us/step - loss: 0.1852 - acc: 0.7240 - val_loss: 0.1996 - val_acc: 0.7135
# Epoch 21/100
# 576/576 [==============================] - 0s 240us/step - loss: 0.1864 - acc: 0.7170 - val_loss: 0.2002 - val_acc: 0.6927
# Epoch 22/100
# 576/576 [==============================] - 0s 234us/step - loss: 0.1847 - acc: 0.7292 - val_loss: 0.2013 - val_acc: 0.6927
# Epoch 23/100
# 576/576 [==============================] - 0s 244us/step - loss: 0.1823 - acc: 0.7361 - val_loss: 0.2000 - val_acc: 0.6979
# Epoch 24/100
# 576/576 [==============================] - 0s 235us/step - loss: 0.1848 - acc: 0.7240 - val_loss: 0.2013 - val_acc: 0.7135
# Epoch 25/100
# 576/576 [==============================] - 0s 256us/step - loss: 0.1818 - acc: 0.7205 - val_loss: 0.1997 - val_acc: 0.7083
# Epoch 26/100
# 576/576 [==============================] - 0s 254us/step - loss: 0.1822 - acc: 0.7170 - val_loss: 0.2014 - val_acc: 0.6875
# Epoch 27/100
# 576/576 [==============================] - 0s 232us/step - loss: 0.1788 - acc: 0.7448 - val_loss: 0.2036 - val_acc: 0.7187
# Epoch 28/100
# 576/576 [==============================] - 0s 250us/step - loss: 0.1840 - acc: 0.7378 - val_loss: 0.1973 - val_acc: 0.7135
# Epoch 29/100
# 576/576 [==============================] - 0s 279us/step - loss: 0.1752 - acc: 0.7483 - val_loss: 0.2033 - val_acc: 0.6979
# Epoch 30/100
# 576/576 [==============================] - 0s 247us/step - loss: 0.1863 - acc: 0.7101 - val_loss: 0.1995 - val_acc: 0.7083
# Epoch 31/100
# 576/576 [==============================] - 0s 223us/step - loss: 0.1798 - acc: 0.7326 - val_loss: 0.2038 - val_acc: 0.6979
# Epoch 32/100
# 576/576 [==============================] - 0s 236us/step - loss: 0.1793 - acc: 0.7483 - val_loss: 0.2082 - val_acc: 0.6927
# Epoch 33/100
# 576/576 [==============================] - 0s 229us/step - loss: 0.1924 - acc: 0.7049 - val_loss: 0.1976 - val_acc: 0.7031
# Epoch 34/100
# 576/576 [==============================] - 0s 270us/step - loss: 0.1808 - acc: 0.7344 - val_loss: 0.2054 - val_acc: 0.7187
# Epoch 35/100
# 576/576 [==============================] - 0s 224us/step - loss: 0.1822 - acc: 0.7240 - val_loss: 0.2033 - val_acc: 0.6823
# Epoch 36/100
# 576/576 [==============================] - 0s 228us/step - loss: 0.1697 - acc: 0.7622 - val_loss: 0.2017 - val_acc: 0.7187
# Epoch 37/100
# 576/576 [==============================] - 0s 254us/step - loss: 0.1739 - acc: 0.7378 - val_loss: 0.1991 - val_acc: 0.7031
# Epoch 38/100
# 576/576 [==============================] - 0s 260us/step - loss: 0.1690 - acc: 0.7465 - val_loss: 0.1991 - val_acc: 0.6979
# Epoch 39/100
# 576/576 [==============================] - 0s 254us/step - loss: 0.1776 - acc: 0.7378 - val_loss: 0.2027 - val_acc: 0.6927
# Epoch 40/100
# 576/576 [==============================] - 0s 263us/step - loss: 0.1731 - acc: 0.7552 - val_loss: 0.2017 - val_acc: 0.7083
# Epoch 41/100
# 576/576 [==============================] - 0s 235us/step - loss: 0.1717 - acc: 0.7431 - val_loss: 0.2000 - val_acc: 0.7135
# Epoch 42/100
# 576/576 [==============================] - 0s 243us/step - loss: 0.1696 - acc: 0.7431 - val_loss: 0.1981 - val_acc: 0.7135
# Epoch 43/100
# 576/576 [==============================] - 0s 273us/step - loss: 0.1673 - acc: 0.7587 - val_loss: 0.1992 - val_acc: 0.7187
# Epoch 44/100
# 576/576 [==============================] - 0s 231us/step - loss: 0.1683 - acc: 0.7587 - val_loss: 0.1989 - val_acc: 0.7187
# Epoch 45/100
# 576/576 [==============================] - 0s 256us/step - loss: 0.1700 - acc: 0.7674 - val_loss: 0.2079 - val_acc: 0.6979
# Epoch 46/100
# 576/576 [==============================] - 0s 276us/step - loss: 0.1670 - acc: 0.7674 - val_loss: 0.1994 - val_acc: 0.7188
# Epoch 47/100
# 576/576 [==============================] - 0s 216us/step - loss: 0.1650 - acc: 0.7604 - val_loss: 0.1989 - val_acc: 0.7187
# Epoch 48/100
# 576/576 [==============================] - 0s 237us/step - loss: 0.1646 - acc: 0.7760 - val_loss: 0.2056 - val_acc: 0.7031
# Epoch 49/100
# 576/576 [==============================] - 0s 235us/step - loss: 0.1632 - acc: 0.7813 - val_loss: 0.2029 - val_acc: 0.7240
# Epoch 50/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1662 - acc: 0.7552 - val_loss: 0.2070 - val_acc: 0.6823
# Epoch 51/100
# 576/576 [==============================] - 0s 255us/step - loss: 0.1640 - acc: 0.7604 - val_loss: 0.2131 - val_acc: 0.6927
# Epoch 52/100
# 576/576 [==============================] - 0s 258us/step - loss: 0.1861 - acc: 0.7031 - val_loss: 0.2068 - val_acc: 0.7031
# Epoch 53/100
# 576/576 [==============================] - 0s 272us/step - loss: 0.1716 - acc: 0.7309 - val_loss: 0.2012 - val_acc: 0.7135
# Epoch 54/100
# 576/576 [==============================] - 0s 228us/step - loss: 0.1651 - acc: 0.7691 - val_loss: 0.2032 - val_acc: 0.7135
# Epoch 55/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1644 - acc: 0.7726 - val_loss: 0.2087 - val_acc: 0.6927
# Epoch 56/100
# 576/576 [==============================] - 0s 233us/step - loss: 0.1712 - acc: 0.7465 - val_loss: 0.2057 - val_acc: 0.7240
# Epoch 57/100
# 576/576 [==============================] - 0s 234us/step - loss: 0.1677 - acc: 0.7587 - val_loss: 0.2051 - val_acc: 0.7083
# Epoch 58/100
# 576/576 [==============================] - 0s 222us/step - loss: 0.1712 - acc: 0.7361 - val_loss: 0.2018 - val_acc: 0.7083
# Epoch 59/100
# 576/576 [==============================] - 0s 226us/step - loss: 0.1615 - acc: 0.7726 - val_loss: 0.2009 - val_acc: 0.7188
# Epoch 60/100
# 576/576 [==============================] - 0s 304us/step - loss: 0.1619 - acc: 0.7726 - val_loss: 0.2009 - val_acc: 0.7187
# Epoch 61/100
# 576/576 [==============================] - 0s 232us/step - loss: 0.1576 - acc: 0.7830 - val_loss: 0.2060 - val_acc: 0.7135
# Epoch 62/100
# 576/576 [==============================] - 0s 241us/step - loss: 0.1606 - acc: 0.7760 - val_loss: 0.2076 - val_acc: 0.7292
# Epoch 63/100
# 576/576 [==============================] - 0s 220us/step - loss: 0.1612 - acc: 0.7691 - val_loss: 0.2043 - val_acc: 0.7135
# Epoch 64/100
# 576/576 [==============================] - 0s 225us/step - loss: 0.1576 - acc: 0.7743 - val_loss: 0.2114 - val_acc: 0.7135
# Epoch 65/100
# 576/576 [==============================] - 0s 241us/step - loss: 0.1683 - acc: 0.7483 - val_loss: 0.2099 - val_acc: 0.6771
# Epoch 66/100
# 576/576 [==============================] - 0s 258us/step - loss: 0.1674 - acc: 0.7639 - val_loss: 0.2044 - val_acc: 0.6927
# Epoch 67/100
# 576/576 [==============================] - 0s 251us/step - loss: 0.1751 - acc: 0.7309 - val_loss: 0.2123 - val_acc: 0.6927
# Epoch 68/100
# 576/576 [==============================] - 0s 411us/step - loss: 0.1698 - acc: 0.7622 - val_loss: 0.2043 - val_acc: 0.6979
# Epoch 69/100
# 576/576 [==============================] - 0s 232us/step - loss: 0.1555 - acc: 0.7882 - val_loss: 0.2022 - val_acc: 0.7187
# Epoch 70/100
# 576/576 [==============================] - 0s 269us/step - loss: 0.1566 - acc: 0.7708 - val_loss: 0.2019 - val_acc: 0.7083
# Epoch 71/100
# 576/576 [==============================] - 0s 253us/step - loss: 0.1578 - acc: 0.7760 - val_loss: 0.2042 - val_acc: 0.7083
# Epoch 72/100
# 576/576 [==============================] - 0s 387us/step - loss: 0.1511 - acc: 0.7795 - val_loss: 0.2044 - val_acc: 0.6771
# Epoch 73/100
# 576/576 [==============================] - 0s 351us/step - loss: 0.1501 - acc: 0.7969 - val_loss: 0.2092 - val_acc: 0.7240
# Epoch 74/100
# 576/576 [==============================] - 0s 242us/step - loss: 0.1556 - acc: 0.7830 - val_loss: 0.2135 - val_acc: 0.7083
# Epoch 75/100
# 576/576 [==============================] - 0s 271us/step - loss: 0.1568 - acc: 0.7639 - val_loss: 0.2072 - val_acc: 0.7083
# Epoch 76/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1684 - acc: 0.7552 - val_loss: 0.2122 - val_acc: 0.6927
# Epoch 77/100
# 576/576 [==============================] - 0s 291us/step - loss: 0.1598 - acc: 0.7778 - val_loss: 0.2051 - val_acc: 0.7240
# Epoch 78/100
# 576/576 [==============================] - 0s 251us/step - loss: 0.1545 - acc: 0.7882 - val_loss: 0.2072 - val_acc: 0.7188
# Epoch 79/100
# 576/576 [==============================] - 0s 255us/step - loss: 0.1491 - acc: 0.7865 - val_loss: 0.2037 - val_acc: 0.7187
# Epoch 80/100
# 576/576 [==============================] - 0s 255us/step - loss: 0.1519 - acc: 0.7830 - val_loss: 0.2083 - val_acc: 0.7031
# Epoch 81/100
# 576/576 [==============================] - 0s 290us/step - loss: 0.1543 - acc: 0.7917 - val_loss: 0.2033 - val_acc: 0.7083
# Epoch 82/100
# 576/576 [==============================] - 0s 320us/step - loss: 0.1511 - acc: 0.7795 - val_loss: 0.2101 - val_acc: 0.6927
# Epoch 83/100
# 576/576 [==============================] - 0s 407us/step - loss: 0.1550 - acc: 0.7865 - val_loss: 0.2042 - val_acc: 0.7188
# Epoch 84/100
# 576/576 [==============================] - 0s 413us/step - loss: 0.1515 - acc: 0.7865 - val_loss: 0.2045 - val_acc: 0.7031
# Epoch 85/100
# 576/576 [==============================] - 0s 261us/step - loss: 0.1551 - acc: 0.7934 - val_loss: 0.2130 - val_acc: 0.7083
# Epoch 86/100
# 576/576 [==============================] - 0s 380us/step - loss: 0.1592 - acc: 0.7639 - val_loss: 0.2121 - val_acc: 0.6875
# Epoch 87/100
# 576/576 [==============================] - 0s 358us/step - loss: 0.1530 - acc: 0.7760 - val_loss: 0.2081 - val_acc: 0.6979
# Epoch 88/100
# 576/576 [==============================] - 0s 381us/step - loss: 0.1506 - acc: 0.7865 - val_loss: 0.2064 - val_acc: 0.7083
# Epoch 89/100
# 576/576 [==============================] - 0s 401us/step - loss: 0.1445 - acc: 0.7847 - val_loss: 0.2065 - val_acc: 0.7031
# Epoch 90/100
# 576/576 [==============================] - 0s 296us/step - loss: 0.1484 - acc: 0.7882 - val_loss: 0.2056 - val_acc: 0.7135
# Epoch 91/100
# 576/576 [==============================] - 0s 411us/step - loss: 0.1459 - acc: 0.7969 - val_loss: 0.2043 - val_acc: 0.7188
# Epoch 92/100
# 576/576 [==============================] - 0s 375us/step - loss: 0.1484 - acc: 0.7795 - val_loss: 0.2092 - val_acc: 0.6979
# Epoch 93/100
# 576/576 [==============================] - 0s 303us/step - loss: 0.1533 - acc: 0.7726 - val_loss: 0.2107 - val_acc: 0.7031
# Epoch 94/100
# 576/576 [==============================] - 0s 278us/step - loss: 0.1477 - acc: 0.7882 - val_loss: 0.2100 - val_acc: 0.7240
# Epoch 95/100
# 576/576 [==============================] - 0s 297us/step - loss: 0.1467 - acc: 0.7951 - val_loss: 0.2106 - val_acc: 0.7031
# Epoch 96/100
# 576/576 [==============================] - 0s 266us/step - loss: 0.1491 - acc: 0.7951 - val_loss: 0.2088 - val_acc: 0.6875
# Epoch 97/100
# 576/576 [==============================] - 0s 279us/step - loss: 0.1525 - acc: 0.7760 - val_loss: 0.2106 - val_acc: 0.6927
# Epoch 98/100
# 576/576 [==============================] - 0s 256us/step - loss: 0.1489 - acc: 0.7847 - val_loss: 0.2147 - val_acc: 0.6979
# Epoch 99/100
# 576/576 [==============================] - 0s 429us/step - loss: 0.1514 - acc: 0.7812 - val_loss: 0.2118 - val_acc: 0.6875
# Epoch 100/100
# 576/576 [==============================] - 0s 339us/step - loss: 0.1496 - acc: 0.7813 - val_loss: 0.2054 - val_acc: 0.7188
# TP - True Negative 96
# FP - False Positive 27
# FN - False Negative 26
# TP - True Positive 43
# Accuracy Rate: 0.7239583333333334
# Misclassification Rate: 0.2760416666666667
# <ipython-input-2-59540b2a70fb>:168: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(500, input_dim=8, activation="relu", kernel_initializer="uniform")`
#   model.add(Dense(500, input_dim=8,init='uniform' ,activation='relu'))
# <ipython-input-2-59540b2a70fb>:169: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, activation="relu", kernel_initializer="uniform")`
#   model.add(Dense(100, init='uniform',activation='relu'))
# <ipython-input-2-59540b2a70fb>:170: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   model.add(Dense(1, init='uniform',activation='sigmoid'))
# Train on 576 samples, validate on 192 samples
# Epoch 1/100
# 576/576 [==============================] - 0s 247us/step - loss: 0.2909 - acc: 0.6354 - val_loss: 0.2527 - val_acc: 0.5208
# Epoch 2/100
# 576/576 [==============================] - 0s 282us/step - loss: 0.2476 - acc: 0.5694 - val_loss: 0.2287 - val_acc: 0.6615
# Epoch 3/100
# 576/576 [==============================] - 0s 277us/step - loss: 0.2249 - acc: 0.6372 - val_loss: 0.2157 - val_acc: 0.6510
# Epoch 4/100
# 576/576 [==============================] - 0s 287us/step - loss: 0.2124 - acc: 0.6719 - val_loss: 0.2134 - val_acc: 0.6927
# Epoch 5/100
# 576/576 [==============================] - 0s 278us/step - loss: 0.2117 - acc: 0.6771 - val_loss: 0.2196 - val_acc: 0.6667
# Epoch 6/100
# 576/576 [==============================] - 0s 275us/step - loss: 0.2103 - acc: 0.6736 - val_loss: 0.2100 - val_acc: 0.6979
# Epoch 7/100
# 576/576 [==============================] - 0s 309us/step - loss: 0.2046 - acc: 0.6823 - val_loss: 0.2056 - val_acc: 0.6979
# Epoch 8/100
# 576/576 [==============================] - 0s 277us/step - loss: 0.2003 - acc: 0.6962 - val_loss: 0.2030 - val_acc: 0.7083
# Epoch 9/100
# 576/576 [==============================] - 0s 280us/step - loss: 0.1991 - acc: 0.6997 - val_loss: 0.2037 - val_acc: 0.6823
# Epoch 10/100
# 576/576 [==============================] - 0s 312us/step - loss: 0.1974 - acc: 0.7135 - val_loss: 0.2076 - val_acc: 0.6719
# Epoch 11/100
# 576/576 [==============================] - 0s 284us/step - loss: 0.2033 - acc: 0.6788 - val_loss: 0.2214 - val_acc: 0.6719
# Epoch 12/100
# 576/576 [==============================] - 0s 292us/step - loss: 0.1929 - acc: 0.7101 - val_loss: 0.2098 - val_acc: 0.6875
# Epoch 13/100
# 576/576 [==============================] - 0s 251us/step - loss: 0.1949 - acc: 0.6997 - val_loss: 0.2027 - val_acc: 0.7187
# Epoch 14/100
# 576/576 [==============================] - 0s 290us/step - loss: 0.1963 - acc: 0.7066 - val_loss: 0.2106 - val_acc: 0.6875
# Epoch 15/100
# 576/576 [==============================] - 0s 257us/step - loss: 0.1947 - acc: 0.7222 - val_loss: 0.2055 - val_acc: 0.6875
# Epoch 16/100
# 576/576 [==============================] - 0s 267us/step - loss: 0.1939 - acc: 0.6944 - val_loss: 0.2239 - val_acc: 0.6875
# Epoch 17/100
# 576/576 [==============================] - 0s 286us/step - loss: 0.1974 - acc: 0.7240 - val_loss: 0.2065 - val_acc: 0.7031
# Epoch 18/100
# 576/576 [==============================] - 0s 235us/step - loss: 0.1898 - acc: 0.7170 - val_loss: 0.1999 - val_acc: 0.6927
# Epoch 19/100
# 576/576 [==============================] - 0s 242us/step - loss: 0.1866 - acc: 0.7188 - val_loss: 0.2002 - val_acc: 0.7031
# Epoch 20/100
# 576/576 [==============================] - 0s 243us/step - loss: 0.1884 - acc: 0.7222 - val_loss: 0.1997 - val_acc: 0.7188
# Epoch 21/100
# 576/576 [==============================] - 0s 243us/step - loss: 0.1821 - acc: 0.7309 - val_loss: 0.1980 - val_acc: 0.7135
# Epoch 22/100
# 576/576 [==============================] - 0s 286us/step - loss: 0.1861 - acc: 0.7222 - val_loss: 0.1964 - val_acc: 0.7031
# Epoch 23/100
# 576/576 [==============================] - 0s 315us/step - loss: 0.1808 - acc: 0.7240 - val_loss: 0.2012 - val_acc: 0.7187
# Epoch 24/100
# 576/576 [==============================] - 0s 290us/step - loss: 0.1814 - acc: 0.7274 - val_loss: 0.2031 - val_acc: 0.6927
# Epoch 25/100
# 576/576 [==============================] - 0s 296us/step - loss: 0.1845 - acc: 0.7240 - val_loss: 0.2001 - val_acc: 0.7083
# Epoch 26/100
# 576/576 [==============================] - 0s 292us/step - loss: 0.1779 - acc: 0.7326 - val_loss: 0.2105 - val_acc: 0.7135
# Epoch 27/100
# 576/576 [==============================] - 0s 261us/step - loss: 0.1927 - acc: 0.7066 - val_loss: 0.2112 - val_acc: 0.7031
# Epoch 28/100
# 576/576 [==============================] - 0s 338us/step - loss: 0.1870 - acc: 0.7187 - val_loss: 0.1990 - val_acc: 0.7031
# Epoch 29/100
# 576/576 [==============================] - 0s 305us/step - loss: 0.1829 - acc: 0.7222 - val_loss: 0.2018 - val_acc: 0.7188
# Epoch 30/100
# 576/576 [==============================] - 0s 331us/step - loss: 0.1791 - acc: 0.7344 - val_loss: 0.2033 - val_acc: 0.7188
# Epoch 31/100
# 576/576 [==============================] - 0s 289us/step - loss: 0.1808 - acc: 0.7274 - val_loss: 0.2013 - val_acc: 0.7031
# Epoch 32/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1747 - acc: 0.7465 - val_loss: 0.2018 - val_acc: 0.7135
# Epoch 33/100
# 576/576 [==============================] - 0s 245us/step - loss: 0.1747 - acc: 0.7378 - val_loss: 0.1963 - val_acc: 0.7396
# Epoch 34/100
# 576/576 [==============================] - 0s 262us/step - loss: 0.1717 - acc: 0.7483 - val_loss: 0.2023 - val_acc: 0.6927
# Epoch 35/100
# 576/576 [==============================] - 0s 292us/step - loss: 0.1717 - acc: 0.7483 - val_loss: 0.1985 - val_acc: 0.7135
# Epoch 36/100
# 576/576 [==============================] - 0s 252us/step - loss: 0.1740 - acc: 0.7222 - val_loss: 0.2000 - val_acc: 0.7083
# Epoch 37/100
# 576/576 [==============================] - 0s 261us/step - loss: 0.1794 - acc: 0.7344 - val_loss: 0.2272 - val_acc: 0.6771
# Epoch 38/100
# 576/576 [==============================] - 0s 257us/step - loss: 0.1997 - acc: 0.7135 - val_loss: 0.2196 - val_acc: 0.7031
# Epoch 39/100
# 576/576 [==============================] - 0s 248us/step - loss: 0.1785 - acc: 0.7187 - val_loss: 0.2129 - val_acc: 0.7031
# Epoch 40/100
# 576/576 [==============================] - 0s 317us/step - loss: 0.1808 - acc: 0.7101 - val_loss: 0.2013 - val_acc: 0.7187
# Epoch 41/100
# 576/576 [==============================] - 0s 274us/step - loss: 0.1800 - acc: 0.7222 - val_loss: 0.1991 - val_acc: 0.7083
# Epoch 42/100
# 576/576 [==============================] - 0s 313us/step - loss: 0.1752 - acc: 0.7326 - val_loss: 0.1996 - val_acc: 0.7240
# Epoch 43/100
# 576/576 [==============================] - 0s 323us/step - loss: 0.1747 - acc: 0.7396 - val_loss: 0.2025 - val_acc: 0.7031
# Epoch 44/100
# 576/576 [==============================] - 0s 267us/step - loss: 0.1735 - acc: 0.7413 - val_loss: 0.2043 - val_acc: 0.7083
# Epoch 45/100
# 576/576 [==============================] - 0s 279us/step - loss: 0.1714 - acc: 0.7622 - val_loss: 0.2044 - val_acc: 0.6927
# Epoch 46/100
# 576/576 [==============================] - 0s 253us/step - loss: 0.1751 - acc: 0.7378 - val_loss: 0.1976 - val_acc: 0.7344
# Epoch 47/100
# 576/576 [==============================] - 0s 278us/step - loss: 0.1680 - acc: 0.7500 - val_loss: 0.2023 - val_acc: 0.6927
# Epoch 48/100
# 576/576 [==============================] - 0s 316us/step - loss: 0.1674 - acc: 0.7587 - val_loss: 0.1995 - val_acc: 0.7240
# Epoch 49/100
# 576/576 [==============================] - 0s 283us/step - loss: 0.1734 - acc: 0.7361 - val_loss: 0.2092 - val_acc: 0.6979
# Epoch 50/100
# 576/576 [==============================] - 0s 279us/step - loss: 0.1753 - acc: 0.7500 - val_loss: 0.2015 - val_acc: 0.7240
# Epoch 51/100
# 576/576 [==============================] - 0s 281us/step - loss: 0.1759 - acc: 0.7465 - val_loss: 0.2015 - val_acc: 0.7031
# Epoch 52/100
# 576/576 [==============================] - 0s 282us/step - loss: 0.1633 - acc: 0.7465 - val_loss: 0.2046 - val_acc: 0.7292
# Epoch 53/100
# 576/576 [==============================] - 0s 256us/step - loss: 0.1710 - acc: 0.7604 - val_loss: 0.2098 - val_acc: 0.7031
# Epoch 54/100
# 576/576 [==============================] - 0s 255us/step - loss: 0.1690 - acc: 0.7500 - val_loss: 0.1995 - val_acc: 0.7031
# Epoch 55/100
# 576/576 [==============================] - 0s 216us/step - loss: 0.1764 - acc: 0.7344 - val_loss: 0.2097 - val_acc: 0.6823
# Epoch 56/100
# 576/576 [==============================] - 0s 277us/step - loss: 0.1837 - acc: 0.7257 - val_loss: 0.2048 - val_acc: 0.6875
# Epoch 57/100
# 576/576 [==============================] - 0s 265us/step - loss: 0.1765 - acc: 0.7396 - val_loss: 0.2034 - val_acc: 0.7187
# Epoch 58/100
# 576/576 [==============================] - 0s 270us/step - loss: 0.1706 - acc: 0.7396 - val_loss: 0.2071 - val_acc: 0.6979
# Epoch 59/100
# 576/576 [==============================] - 0s 292us/step - loss: 0.1637 - acc: 0.7535 - val_loss: 0.2013 - val_acc: 0.7240
# Epoch 60/100
# 576/576 [==============================] - 0s 326us/step - loss: 0.1629 - acc: 0.7552 - val_loss: 0.2016 - val_acc: 0.7135
# Epoch 61/100
# 576/576 [==============================] - 0s 318us/step - loss: 0.1611 - acc: 0.7500 - val_loss: 0.2019 - val_acc: 0.7083
# Epoch 62/100
# 576/576 [==============================] - 0s 263us/step - loss: 0.1612 - acc: 0.7708 - val_loss: 0.2023 - val_acc: 0.7135
# Epoch 63/100
# 576/576 [==============================] - 0s 251us/step - loss: 0.1621 - acc: 0.7622 - val_loss: 0.2017 - val_acc: 0.7240
# Epoch 64/100
# 576/576 [==============================] - 0s 249us/step - loss: 0.1597 - acc: 0.7622 - val_loss: 0.2091 - val_acc: 0.6979
# Epoch 65/100
# 576/576 [==============================] - 0s 274us/step - loss: 0.1667 - acc: 0.7587 - val_loss: 0.2052 - val_acc: 0.7187
# Epoch 66/100
# 576/576 [==============================] - 0s 310us/step - loss: 0.1618 - acc: 0.7552 - val_loss: 0.2038 - val_acc: 0.6979
# Epoch 67/100
# 576/576 [==============================] - 0s 300us/step - loss: 0.1581 - acc: 0.7760 - val_loss: 0.2042 - val_acc: 0.7031
# Epoch 68/100
# 576/576 [==============================] - 0s 275us/step - loss: 0.1596 - acc: 0.7726 - val_loss: 0.2055 - val_acc: 0.7135
# Epoch 69/100
# 576/576 [==============================] - 0s 265us/step - loss: 0.1581 - acc: 0.7587 - val_loss: 0.2067 - val_acc: 0.7135
# Epoch 70/100
# 576/576 [==============================] - 0s 293us/step - loss: 0.1610 - acc: 0.7569 - val_loss: 0.2056 - val_acc: 0.7187
# Epoch 71/100
# 576/576 [==============================] - 0s 265us/step - loss: 0.1660 - acc: 0.7587 - val_loss: 0.2032 - val_acc: 0.6927
# Epoch 72/100
# 576/576 [==============================] - 0s 297us/step - loss: 0.1592 - acc: 0.7639 - val_loss: 0.2063 - val_acc: 0.6979
# Epoch 73/100
# 576/576 [==============================] - 0s 247us/step - loss: 0.1571 - acc: 0.7656 - val_loss: 0.2065 - val_acc: 0.7083
# Epoch 74/100
# 576/576 [==============================] - 0s 273us/step - loss: 0.1581 - acc: 0.7674 - val_loss: 0.2051 - val_acc: 0.7031
# Epoch 75/100
# 576/576 [==============================] - 0s 285us/step - loss: 0.1579 - acc: 0.7500 - val_loss: 0.2100 - val_acc: 0.7135
# Epoch 76/100
# 576/576 [==============================] - 0s 271us/step - loss: 0.1593 - acc: 0.7691 - val_loss: 0.2089 - val_acc: 0.6823
# Epoch 77/100
# 576/576 [==============================] - 0s 296us/step - loss: 0.1530 - acc: 0.8003 - val_loss: 0.2120 - val_acc: 0.6979
# Epoch 78/100
# 576/576 [==============================] - 0s 299us/step - loss: 0.1634 - acc: 0.7656 - val_loss: 0.2186 - val_acc: 0.6979
# Epoch 79/100
# 576/576 [==============================] - 0s 296us/step - loss: 0.1666 - acc: 0.7604 - val_loss: 0.2127 - val_acc: 0.6771
# Epoch 80/100
# 576/576 [==============================] - 0s 283us/step - loss: 0.1591 - acc: 0.7622 - val_loss: 0.2049 - val_acc: 0.6927
# Epoch 81/100
# 576/576 [==============================] - 0s 279us/step - loss: 0.1546 - acc: 0.7795 - val_loss: 0.2101 - val_acc: 0.7031
# Epoch 82/100
# 576/576 [==============================] - 0s 311us/step - loss: 0.1488 - acc: 0.7812 - val_loss: 0.2142 - val_acc: 0.6927
# Epoch 83/100
# 576/576 [==============================] - 0s 269us/step - loss: 0.1554 - acc: 0.7899 - val_loss: 0.2210 - val_acc: 0.6927
# Epoch 84/100
# 576/576 [==============================] - 0s 275us/step - loss: 0.1654 - acc: 0.7396 - val_loss: 0.2224 - val_acc: 0.6562
# Epoch 85/100
# 576/576 [==============================] - 0s 306us/step - loss: 0.1627 - acc: 0.7656 - val_loss: 0.2076 - val_acc: 0.7135
# Epoch 86/100
# 576/576 [==============================] - 0s 282us/step - loss: 0.1617 - acc: 0.7552 - val_loss: 0.2108 - val_acc: 0.6823
# Epoch 87/100
# 576/576 [==============================] - 0s 282us/step - loss: 0.1546 - acc: 0.7760 - val_loss: 0.2071 - val_acc: 0.7031
# Epoch 88/100
# 576/576 [==============================] - 0s 285us/step - loss: 0.1533 - acc: 0.7778 - val_loss: 0.2076 - val_acc: 0.6979
# Epoch 89/100
# 576/576 [==============================] - 0s 282us/step - loss: 0.1537 - acc: 0.7778 - val_loss: 0.2113 - val_acc: 0.6875
# Epoch 90/100
# 576/576 [==============================] - 0s 277us/step - loss: 0.1506 - acc: 0.7830 - val_loss: 0.2130 - val_acc: 0.6875
# Epoch 91/100
# 576/576 [==============================] - 0s 278us/step - loss: 0.1564 - acc: 0.7656 - val_loss: 0.2133 - val_acc: 0.7031
# Epoch 92/100
# 576/576 [==============================] - 0s 300us/step - loss: 0.1571 - acc: 0.7517 - val_loss: 0.2114 - val_acc: 0.7031
# Epoch 93/100
# 576/576 [==============================] - 0s 318us/step - loss: 0.1575 - acc: 0.7691 - val_loss: 0.2119 - val_acc: 0.6875
# Epoch 94/100
# 576/576 [==============================] - 0s 286us/step - loss: 0.1499 - acc: 0.7795 - val_loss: 0.2110 - val_acc: 0.6927
# Epoch 95/100
# 576/576 [==============================] - 0s 306us/step - loss: 0.1492 - acc: 0.7778 - val_loss: 0.2119 - val_acc: 0.6927
# Epoch 96/100
# 576/576 [==============================] - 0s 260us/step - loss: 0.1472 - acc: 0.7778 - val_loss: 0.2128 - val_acc: 0.7031
# Epoch 97/100
# 576/576 [==============================] - 0s 289us/step - loss: 0.1515 - acc: 0.7760 - val_loss: 0.2159 - val_acc: 0.6927
# Epoch 98/100
# 576/576 [==============================] - 0s 250us/step - loss: 0.1520 - acc: 0.7674 - val_loss: 0.2061 - val_acc: 0.7292
# Epoch 99/100
# 576/576 [==============================] - 0s 298us/step - loss: 0.1573 - acc: 0.7778 - val_loss: 0.2041 - val_acc: 0.7188
# Epoch 100/100
# 576/576 [==============================] - 0s 275us/step - loss: 0.1503 - acc: 0.7899 - val_loss: 0.2126 - val_acc: 0.7187
